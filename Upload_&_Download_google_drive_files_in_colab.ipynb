# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/vk1996/colab_demos/blob/master/Upload_&_Download_google_drive_files_in_colab.ipynb)

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('drive')
# !ls
# Out:
# Mounted at drive
# adc.json  drive  IMG_3684.PNG  sample_data  test.jpg

# %%
#get your local helper your function here
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4c64485e-bd52-476d-b620-ea1600b9d497" name="files[]" multiple disabled />
#      <output id="result-4c64485e-bd52-476d-b620-ea1600b9d497">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test.jpg to test.jpg

# %%
from cv2 import imread
y=imread('drive/My Drive/**filename in your drive**') # READS IN NUMPY ARRAY
print (y)
from matplotlib import pyplot as plt
plt.imshow(y)
# !ls
# Out:
# [[[248 243 240]
#   [248 243 240]
#   [248 243 240]
#   ...
#   [246 241 240]
#   [246 241 240]
#   [246 241 240]]
#
#  [[248 243 240]
#   [248 243 240]
#   [248 243 240]
#   ...
#   [246 241 240]
#   [246 241 240]
#   [246 241 240]]
#
#  [[248 243 240]
#   [248 243 240]
#   [248 243 240]
#   ...
#   [246 241 240]
#   [246 241 240]
#   [246 241 240]]
#
#  ...
#
#  [[ 96 121 137]
#   [106 131 147]
#   [100 125 141]
#   ...
#   [121 141 158]
#   [111 127 139]
#   [241 254 255]]
#
#  [[ 98 123 139]
#   [ 94 119 135]
#   [ 95 120 136]
#   ...
#   [119 139 156]
#   [ 94 110 122]
#   [239 251 255]]
#
#  [[ 97 122 138]
#   [ 92 117 133]
#   [ 97 122 138]
#   ...
#   [ 98 118 135]
#   [ 91 107 120]
#   [240 252 255]]]
# adc.json  drive  IMG_3684.PNG  sample_data  test.jpg

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Create & upload a file.
uploaded = drive.CreateFile({'title': 'test1.jpg'})
uploaded.SetContentFile('test.jpg')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1j9LHGjG9vkE6JHfVj6R6f0Q_GVSoi7Ww
